# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
PATH = "./burritos.csv"
df = pd.read_csv(PATH)

# %%
df.shape
# Out:
# (423, 66)

# %%
#df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 423 entries, 0 to 422
# Data columns (total 66 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Location        423 non-null    object
#  1   Burrito         423 non-null    object
#  2   Date            423 non-null    object
#  3   Neighborhood    92 non-null     object
#  4   Address         88 non-null     object
#  5   URL             87 non-null     object
#  6   Yelp            87 non-null     float64
#  7   Google          87 non-null     float64
#  8   Chips           26 non-null     object
#  9   Cost            416 non-null    float64
#  10  Hunger          420 non-null    float64
#  11  Mass (g)        22 non-null     float64
#  12  Density (g/mL)  22 non-null     float64
#  13  Length          284 non-null    float64
#  14  Circum          282 non-null    float64
#  15  Volume          282 non-null    float64
#  16  Tortilla        423 non-null    float64
# ...

# %%
#histogram plot for all columns before handling
df.isnull().sum().sort_values().plot(kind="barh",
                                     title="Missing Values (Shape: 423, 66)",
                                     ylabel="column name",
                                    figsize=(15,14));

# %%
f = "F"

df["Shrimp"] = df["Shrimp"].replace(np.NaN, f)
df["Chicken"] = df["Chicken"].replace(np.NaN, f)
df["Pork"] = df["Pork"].replace(np.NaN, f)
df["Sour cream"] = df["Sour cream"].replace(np.NaN, f)
df["Fries"] = df["Fries"].replace(np.NaN, f)
df["Cheese"] = df["Cheese"].replace(np.NaN, f)
df["Guac"] = df["Guac"].replace(np.NaN, f)
df["Pico"] = df["Pico"].replace(np.NaN, f)
df["Beef"] = df["Beef"].replace(np.NaN, f)
df["Corn"] = df["Corn"].replace(np.NaN, f)
df["Zucchini"] = df["Zucchini"].replace(np.NaN, f)
df["Avocado"] = df["Avocado"].replace(np.NaN, f)
df["Sushi"] = df["Sushi"].replace(np.NaN, f)
df["Bacon"] = df["Bacon"].replace(np.NaN, f)
df["Mushroom"] = df["Mushroom"].replace(np.NaN, f)
df["Egg"] = df["Egg"].replace(np.NaN, f)
df["Queso"] = df["Queso"].replace(np.NaN, f)
df["Lobster"] = df["Lobster"].replace(np.NaN, f)
df["Nopales"] = df["Nopales"].replace(np.NaN, f)
df["Chile relleno"] = df["Chile relleno"].replace(np.NaN, f)
df["Ham"] = df["Ham"].replace(np.NaN, f)
df["Pineapple"] = df["Pineapple"].replace(np.NaN, f)
df["Taquito"] = df["Taquito"].replace(np.NaN, f)
df["Onion"] = df["Onion"].replace(np.NaN, f)
df["Cilantro"] = df["Cilantro"].replace(np.NaN, f)
df["Sauce"] = df["Sauce"].replace(np.NaN, f)
df["Cabbage"] = df["Cabbage"].replace(np.NaN, f)
df["Carrots"] = df["Carrots"].replace(np.NaN, f)
df["Bell peper"] = df["Bell peper"].replace(np.NaN, f)
df["Tomato"] = df["Tomato"].replace(np.NaN, f)
df["Lettuce"] = df["Lettuce"].replace(np.NaN, f)
df["Beans"] = df["Beans"].replace(np.NaN, f)
df["Rice"] = df["Rice"].replace(np.NaN, f)
df["Fish"] = df["Fish"].replace(np.NaN, f)
df["Chips"] = df["Chips"].replace(np.NaN, f)

# %%
# F mean False, x mean True
df
# Out:
#                      Location        Burrito       Date Neighborhood  \
# 0          Donato's taco shop    California   1/18/2016      Miramar
# 1        Oscar's Mexican food    California   1/24/2016   San Marcos
# 2        Oscar's Mexican food       Carnitas  1/24/2016          NaN
# 3        Oscar's Mexican food    Carne asada  1/24/2016          NaN
# 4                Pollos Maria     California  1/27/2016     Carlsbad
# ..                        ...            ...        ...          ...
# 418  Valentine's Mexican Food      Al Pastor  8/27/2019          NaN
# 419  Valentine's Mexican Food  Chile Relleno  8/27/2019          NaN
# 420  Valentine's Mexican Food     California  8/27/2019          NaN
# 421  Valentine's Mexican Food         Shrimp  8/27/2019          NaN
# 422  Valentine's Mexican Food    Pollo Asado  8/27/2019          NaN
#
#                       Address  \
# 0             6780 Miramar Rd
# 1    225 S Rancho Santa Fe Rd
# 2                         NaN
# ...

# %%
df = df.drop(columns=['Salsa.1', 'Mass (g)', 'NonSD'])

# %%
#Determine how many missing values are present in each column..
df.isnull().sum()
# Out:
# Location          0
# Burrito           0
# Date              0
# Neighborhood    331
# Address         335
#                ...
# Bacon             0
# Sushi             0
# Avocado           0
# Corn              0
# Zucchini          0
# Length: 63, dtype: int64

# %%
#___________________________________________________________________
#Choose a column and replace NaN values with the mean..
df["Salsa"]
# Out:
# 0      4.0
# 1      3.5
# 2      3.0
# 3      4.0
# 4      2.5
#       ...
# 418    2.0
# 419    5.0
# 420    3.5
# 421    5.0
# 422    3.0
# Name: Salsa, Length: 423, dtype: float64

# %%
df["Salsa"].plot(kind="hist", bins=18, title="Histogram of Salsa Column without Handled NaN Values");

# %%
salsa_mean = round(df["Salsa"].mean())
salsa_mean
# Out:
# 3

# %%
df["Salsa"] = df["Salsa"].replace(np.NaN, salsa_mean)
df["Salsa"].isnull().sum()
# Out:
# 0

# %%
df["Salsa"].plot(kind="hist", bins=18, title="Histogram of Salsa Column with Handled NaN Values");

# %%
#___________________________________________________________________
#Choose a column and replace NaN values with the median..
df["Length"]
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 418    17.0
# 419    19.0
# 420    20.0
# 421    22.5
# 422    17.0
# Name: Length, Length: 423, dtype: float64

# %%
df["Length"].plot(kind="hist", bins=20, title="Histogram of Temp column without Handled NaN Values");

# %%
length_median = round(df["Length"].mean())
length_median
# Out:
# 20

# %%
df["Length"] = df["Length"].replace(np.NaN, length_median)

# %%
df["Length"].plot(kind="hist", bins=20, title="Histogram of Temp column with Handled NaN Values");

# %%
#___________________________________________________________________
#Choose a column and replace NaN values with the mode..
df["Temp"]
# Out:
# 0      5.0
# 1      3.5
# 2      2.0
# 3      2.0
# 4      5.0
#       ...
# 418    4.0
# 419    5.0
# 420    4.0
# 421    2.0
# 422    5.0
# Name: Temp, Length: 423, dtype: float64

# %%
df["Temp"].plot(kind="hist", bins=20, title="Histogram of Temp column without Handled NaN Values");

# %%
temp_mode = df["Temp"].mode()[0]
temp_mode
# Out:
# 4.0

# %%
df["Temp"] = df["Temp"].replace(np.NaN, temp_mode)

# %%
df["Temp"].plot(kind="hist", bins=20, title="Histogram of Temp column with Handled NaN Values");

# %%
#___________________________________________________________________
#Choose a column and replace NaN values with your own value
df["Circum"]
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 418    20.5
# 419    26.0
# 420    22.0
# 421    24.5
# 422    21.3
# Name: Circum, Length: 423, dtype: float64

# %%
df["Circum"].plot(kind="hist", bins=20, title="Histogram of Temp column without Handled NaN Values");

# %%
circum_unknown = 23
circum_unknown
# Out:
# 23

# %%
df["Circum"] = df["Circum"].replace(np.NaN, circum_unknown)

# %%
df["Circum"].plot(kind="hist", bins=18, title="Histogram of Temp column with Handled NaN Values");

# %%
#___________________________________________________________________
#Choose a column and use backward filling
df["Yelp"]
# Out:
# 0      3.5
# 1      3.5
# 2      NaN
# 3      NaN
# 4      4.0
#       ...
# 418    NaN
# 419    NaN
# 420    NaN
# 421    NaN
# 422    NaN
# Name: Yelp, Length: 423, dtype: float64

# %%
df["Yelp"].fillna(method="bfill")
# Out:
# 0      3.5
# 1      3.5
# 2      4.0
# 3      4.0
# 4      4.0
#       ...
# 418    NaN
# 419    NaN
# 420    NaN
# 421    NaN
# 422    NaN
# Name: Yelp, Length: 423, dtype: float64

# %%
#___________________________________________________________________
#Choose a column and use forwards filling
df["Neighborhood"]
# Out:
# 0         Miramar
# 1      San Marcos
# 2             NaN
# 3             NaN
# 4        Carlsbad
#           ...
# 418           NaN
# 419           NaN
# 420           NaN
# 421           NaN
# 422           NaN
# Name: Neighborhood, Length: 423, dtype: object

# %%
df["Neighborhood"].fillna(method="ffill")
# Out:
# 0         Miramar
# 1      San Marcos
# 2      San Marcos
# 3      San Marcos
# 4        Carlsbad
#           ...
# 418      Carlsbad
# 419      Carlsbad
# 420      Carlsbad
# 421      Carlsbad
# 422      Carlsbad
# Name: Neighborhood, Length: 423, dtype: object

# %%
#histogram plot for all columns after handling
df.isnull().sum().sort_values().plot(kind="barh",
                                     title="Missing Values (Shape: 423, 66)",
                                     ylabel="column name",
                                    figsize=(15,14));
